# %%
# !pip install streamlit transformers sentencepiece accelerate diffusers torch pillow pyngrok -q

# %%
# !ngrok authtoken 30u73qXNft0Q62PVpksvxNtJpDL_3tcrS81bV65erRQhQXQkG
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
import subprocess, threading, time

def run_streamlit():
    subprocess.Popen([
        "streamlit", "run", "emotion1_app.py",
        "--server.port", "8501",
        "--server.headless", "true",
        "--server.enableCORS", "false",
        "--server.enableXsrfProtection", "false"
    ])

# Start Streamlit
run_streamlit()

# Wait longer for Streamlit to fully boot
print("⏳ Waiting for Streamlit to start...")
time.sleep(10)  # ← increased from 3 to 10 seconds

# Now start ngrok
from pyngrok import ngrok

# Terminate any ngrok tunnels already running
ngrok.kill()

public_url = ngrok.connect(8501)
print("✅ App is live at:", public_url)
# Out:
# ⏳ Waiting for Streamlit to start...
# ✅ App is live at: NgrokTunnel: "https://7af5-104-199-123-57.ngrok-free.app" -> "http://localhost:8501"

# %%
from pyngrok import ngrok

ngrok.kill()  # kills all existing sessions
